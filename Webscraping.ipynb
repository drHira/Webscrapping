# %%
import requests
# to check website status (check status code websites for more details)
url = "https://www.hindustantimes.com/latest-news/"
r = requests.get(url)
print(r.status_code)
# Out:
# 401

# %%
url = "https://courses.wscubetech.com/s/store/courses/"
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %%
# html text
url = "https://courses.wscubetech.com/s/store/courses/"
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#
#
#
#
#
#
#
#
#
# 				<title>WsCube Tech courses</title>
# 				<meta name="description" content="Your online coures store. Explore courses now">
# 				<meta name="keywords" content="Courses store, WsCube Tech">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#
#
#
#
#
#
#
#
#
#
#
#     <meta name="google" content="notranslate">
#
#
#
# <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">
# <link rel="icon" href="/favicon.ico" type="image/x-icon">
#
#
#
#
#
#
#
#
# 		<script>var orgCountry = "IN";</script>
#
#
#
# <link id="theme" href="https://dz8fbjd9gwp2s.cloudfront.net/resources/themes/default/spectre.min.css" rel="stylesheet">
#
# <link rel="preconnect" href="https://fonts.googleapis.com">
# <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
# to check website status (check status code websites for more details)
url = "https://courses.wscubetech.com/s/store/courses/"
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup
# to check website status (check status code websites for more details)
url = "https://courses.wscubetech.com/s/store/courses/"
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#
#
#
#
#
#
#
#
#
# 				<title>WsCube Tech courses</title>
# 				<meta name="description" content="Your online coures store. Explore courses now">
# 				<meta name="keywords" content="Courses store, WsCube Tech">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#
#
#
#
#
#
#
#
#
#
#
#     <meta name="google" content="notranslate">
#
#
#
# <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">
# <link rel="icon" href="/favicon.ico" type="image/x-icon">
#
#
#
#
#
#
#
#
# 		<script>var orgCountry = "IN";</script>
#
#
#
# <link id="theme" href="https://dz8fbjd9gwp2s.cloudfront.net/resources/themes/default/spectre.min.css" rel="stylesheet">
#
# <link rel="preconnect" href="https://fonts.googleapis.com">
# <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
#
# ...

# %%
soup = BeautifulSoup(r.text,"lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>WsCube Tech courses</title>
# <meta content="Your online coures store. Explore courses now" name="description"/>
# <meta content="Courses store, WsCube Tech" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="notranslate" name="google"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <script>var orgCountry = "IN";</script>
# <link href="https://dz8fbjd9gwp2s.cloudfront.net/resources/themes/default/spectre.min.css" id="theme" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link as="style" href="https://fonts.googleapis.com/icon?family=Material+Icons|Material+Icons+Outlined" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# ...

# %%
url = "https://webscraper.io/test-sites/e-commerce/allinone"
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %%
url = "https://webscraper.io/test-sites/e-commerce/allinone"
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# 	<title>Allinone | Web Scraper Test Sites</title>
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#
# 	<meta name="keywords"
# 		  content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper"/>
# 	<meta name="description"
# ...

# %%
url = "https://webscraper.io/test-sites/e-commerce/allinone/computers"
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %%
url = "https://webscraper.io/test-sites/e-commerce/allinone/computers"
r = requests.get(url)
soup = BeautifulSoup(r.text,"lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Allinone | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# ...

# %%
url = "https://webscraper.io/test-sites/e-commerce/allinone/computers"
r = requests.get(url)
soup = BeautifulSoup(r.text,"lxml")
# print(soup.div)
# print(soup.div.a)
# print(soup.ul)
# print(soup.p)
tag = soup.header
atb = tag.attrs
# print(atb["class"])
# print(atb["role"])
tag =soup.div.p.string
print(tag)
# Out:
# Web Scraper

# %%
import requests
from bs4 import BeautifulSoup
url = "https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets/"
r = requests.get(url)
soup = BeautifulSoup(r.text,"lxml")
# price = soup.find("h4",{"class":"float-end price card-title pull-right"})
# price = soup.find("p",{"class":"description card-text"})
# price = soup.find("p",{"class":"float-end review-count"})
# price = soup.find("p",{"class":"data-rating"})
print(price.string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 10
#       6 # price = soup.find("h4",{"class":"float-end price card-title pull-right"})
#       7 # price = soup.find("p",{"class":"description card-text"})
#       8 # price = soup.find("p",{"class":"float-end review-count"})
#       9 price = soup.find("p",{"class":"data-rating"})
# ---> 10 print(price.string)
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %%
import requests
from bs4 import BeautifulSoup
url = "https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets"
r = requests.get(url)
desc = soup.find_all("p",class_ ="description card-text")
# print(desc)
prices = soup.find_all("h4",class_ = "float-end price card-title pull-right")
for i in desc:
    print(i.text)
for j in prices:
    print(j.text)
# Out:
# 7" screen, Android
# Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2
# 7" screen, Android, 16GB
# 7", 8GB, Wi-Fi, Android 4.2, White
# Black, 7", 1.6GHz Dual-Core, 8GB, Android 4.4
# IPS, Dual-Core 1.2GHz, 8GB, Android 4.3
# 7" screen, Android, 8GB
# 6" screen, wifi
# 7", 8GB, Wi-Fi, Android 4.2, Yellow
# Blue, 8" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2
# White, 7", Atom 1.2GHz, 8GB, Android 4.4
# Blue, 7" IPS, Quad-Core 1.3GHz, 8GB, 3G, Android 4.2
# Silver, 7" IPS, Quad-Core 1.2Ghz, 16GB, 3G, Android 4.2
# LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black
# 16GB, White
# White, 10.1" IPS, 1.6GHz, 2GB, 16GB, Android 4.2
# 10.1", 3G, Android 4.0, Garnet Red
# 12.2", 32GB, WiFi, Android 4.4, White
# Wi-Fi + Cellular, 32GB, Silver
# 10.1", 32GB, Black
# Wi-Fi, 64GB, Silver
# $69.99
# $88.99
# $96.99
# $97.99
# $99.99
# $101.99
# $102.99
# $103.99
# $107.99
# $121.99
# $130.99
# $148.99
# $172.99
# $233.99
# $251.99
# $320.99
# $399.99
# $489.99
# $537.99
# $587.99
# $603.99

# %%
import requests
from bs4 import BeautifulSoup
import re
url = "https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets"
r = requests.get(url)
soup = BeautifulSoup(r.text,"lxml")
x = soup.find_all(string = re.compile("Idea"))
print(x)
# Out:
# ['Lenovo IdeaTab', 'IdeaTab A3500L', 'IdeaTab A8-50', 'IdeaTab A3500-...', 'IdeaTab S5000']

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.wscubetech.com/"
r = requests.ger(url)
soup = BeautifulSoup(r.text,"lxml")

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
url = "https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets?"
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")
names = soup.find_all("a", class_ = "title")
product_names=[]
for i in names:
    name = i.text
    product_names.append(name)
# print(product_names)
price = soup.find_all("h4", class_ = "float-end price card-title pull-right")
prices=[]
for i in price:
    price = i.text
    prices.append(price)
# print(prices)
desc = soup.find_all('p',class_ = "description card-text")
description = []
for j in desc:
    des = j.text
    description.append(des)
# print(description)

reviews = soup.find_all("p",class_ = "float-end review-count")
review_list =[]

for j in reviews:
    rev = j.text
    review_list.append(rev)
# print(review_list)

df =pd.DataFrame({"Product Name":product_names,"Price":prices,"Description":description,"Reviews":review_list})
print(df)

# df.to_csv("product_details.csv")
df.to_excel("product_details.xlsx")
# Out:
#          Product Name    Price  \
# 0      Lenovo IdeaTab   $69.99
# 1      IdeaTab A3500L   $88.99
# 2         Acer Iconia   $96.99
# 3        Galaxy Tab 3   $97.99
# 4   Iconia B1-730H...   $99.99
# 5       Memo Pad HD 7  $101.99
# 6       Asus MeMO Pad  $102.99
# 7       Amazon Kindle  $103.99
# 8        Galaxy Tab 3  $107.99
# 9       IdeaTab A8-50  $121.99
# 10         MeMO Pad 7  $130.99
# 11  IdeaTab A3500-...  $148.99
# 12      IdeaTab S5000  $172.99
# 13       Galaxy Tab 4  $233.99
# 14         Galaxy Tab  $251.99
# 15  MeMo PAD FHD 1...  $320.99
# 16        Galaxy Note  $399.99
# 17        Galaxy Note  $489.99
# 18  iPad Mini Reti...  $537.99
# 19  Galaxy Note 10...  $587.99
# 20     Apple iPad Air  $603.99
#
#                                           Description     Reviews
# 0                                  7" screen, Android   7 reviews
# 1   Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2   7 reviews
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = "https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets"
r = requests.get(url)
soup = BeautifulSoup(r.text,"lxml")
# boxes = soup.find_all("div",class_ = "col-md-4 col-xl-4 col-lg-4")[5]
# name = boxes.find("a").text
# print(name)
# desc = boxes.find("p",class_ = "description card-text").text
# print(desc)

navbar = soup.find("ul",class_= "nav flex-column", id = "side-menu")
# print(navbar)
ind = (soup.find_all("ul",class_= "nav-item"))

print(ind)
# Out:
# []

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url ="https://ticker.finology.in/"
r = requests.get(url)
# print(r.status_code)
soup = BeautifulSoup(r.text,"lxml")
tables = soup.find("table", class_ ="table table-sm table-hover screenertable")
# print(tables)
header = tables.find_all("th")
# print(header)
titles = []
for i in header:
    title = i.text
    titles.append(title)
# print(titles)
df = pd.DataFrame(columns=titles)
# print(df)

rows = tables.find_all("tr")
# row_data =[]
for i in rows[1:]:
    data = i.find_all("td")
    rows = [tr.text for tr in data]
#     print(rows)
    l=len(rows)
    df.loc[l] = rows
#     print(df)
#     df.to_csv("car_prices_data.csv")
#     print(df)
    df.to_excel("car_prices_data.xlsx")
    print(df)
#     row = i.text
#     row_data.append(row)

# print(row_data)
# Out:
#              Company  PriceRs. Day HighRs.
# 3  \nMaruti Suzuki\n  10560.70    10845.00
#            Company PriceRs. Day HighRs.
# 3  \nCanara Bank\n   380.80      387.80
#                Company PriceRs. Day HighRs.
# 3  \nShriram Finance\n  1935.20     2029.70
#            Company PriceRs. Day HighRs.
# 3  \nSwan Energy\n   369.20      390.00
#                   Company PriceRs. Day HighRs.
# 3  \nPersistent Systems\n  6083.75     6145.50
#    Company PriceRs. Day HighRs.
# 3  \nBSE\n  1862.95     1912.80
#               Company PriceRs. Day HighRs.
# 3  \nWelspun Living\n   145.70      147.40
#          Company PriceRs. Day HighRs.
# 3  \nAngel One\n  2535.80     2549.15
#                Company PriceRs. Day HighRs.
# 3  \nIndo Count Inds\n   264.70      274.70
#                Company PriceRs. Day HighRs.
# 3  \nSonata Software\n  1177.55     1195.75
#      Company PriceRs. Day HighRs.
# 3  \nCupid\n   602.50      627.00
#                     Company PriceRs. Day HighRs.
# ...
